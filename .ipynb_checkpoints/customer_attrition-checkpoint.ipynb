# %% [markdown]
# # Predicting Bank Customer Attrition
# By Lance Belen

# %% [markdown]
# <h2><u>Data Retrieval and Preparation</u></h2>

# %%
import pandas as pd
df = pd.read_csv("BankChurners.csv")
df.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# 1              44  ...        8256.0                  864           7392.0
# 2              36  ...        3418.0                    0           3418.0
# 3              34  ...        3313.0                 2517            796.0
# 4              21  ...        4716.0                    0           4716.0
#
#    Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  \
# 0                 1.335             1144              42                1.625
# 1                 1.541             1291              33                3.714
# 2                 2.594             1887              20                2.333
# 3                 1.405             1171              20                2.333
# 4                 2.175              816              28                2.500
#
#    Avg_Utilization_Ratio  \
# 0                  0.061
# 1                  0.105
# 2                  0.000
# 3                  0.760
# 4                  0.000
#
#    Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1  \
# 0                                           0.000093
# 1                                           0.000057
# 2                                           0.000021
# 3                                           0.000134
# 4                                           0.000022
#
#    Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2
# 0                                            0.99991
# 1                                            0.99994
# 2                                            0.99998
# 3                                            0.99987
# 4                                            0.99998
#
# [5 rows x 23 columns]

# %%
df.shape
# Out:
# (10127, 23)

# %%
df.dtypes
# Out:
# CLIENTNUM                                                                                                                               int64
# Attrition_Flag                                                                                                                         object
# Customer_Age                                                                                                                            int64
# Gender                                                                                                                                 object
# Dependent_count                                                                                                                         int64
# Education_Level                                                                                                                        object
# Marital_Status                                                                                                                         object
# Income_Category                                                                                                                        object
# Card_Category                                                                                                                          object
# Months_on_book                                                                                                                          int64
# Total_Relationship_Count                                                                                                                int64
# Months_Inactive_12_mon                                                                                                                  int64
# Contacts_Count_12_mon                                                                                                                   int64
# Credit_Limit                                                                                                                          float64
# Total_Revolving_Bal                                                                                                                     int64
# Avg_Open_To_Buy                                                                                                                       float64
# Total_Amt_Chng_Q4_Q1                                                                                                                  float64
# Total_Trans_Amt                                                                                                                         int64
# Total_Trans_Ct                                                                                                                          int64
# Total_Ct_Chng_Q4_Q1                                                                                                                   float64
# Avg_Utilization_Ratio                                                                                                                 float64
# Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1    float64
# Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2    float64
# dtype: object

# %% [markdown]
# <h3><i>Data Pre-Processing</i></h3>

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_cleaned = df.copy()
df_cleaned = df_cleaned.drop(['Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1', 'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'], axis=1)
df_cleaned.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# 0              39  ...                       1                      3
# 1              44  ...                       1                      2
# 2              36  ...                       1                      0
# 3              34  ...                       4                      1
# 4              21  ...                       1                      0
#
#    Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  \
# 0       12691.0                  777          11914.0                 1.335
# 1        8256.0                  864           7392.0                 1.541
# 2        3418.0                    0           3418.0                 2.594
# 3        3313.0                 2517            796.0                 1.405
# 4        4716.0                    0           4716.0                 2.175
#
#    Total_Trans_Amt  Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio
# 0             1144              42                1.625                  0.061
# 1             1291              33                3.714                  0.105
# 2             1887              20                2.333                  0.000
# 3             1171              20                2.333                  0.760
# 4              816              28                2.500                  0.000
#
# [5 rows x 21 columns]

# %% [markdown]
# <h4><u>Remove outliers</u></h4>

# %%
for col in df_cleaned.columns:
    if df[col].dtype == 'int':
        Q1 = df_cleaned[col].quantile(0.25)
        Q3 = df_cleaned[col].quantile(0.75)
        IQR = Q3 - Q1
        threshold = 1.5
        outliers = df_cleaned[(df_cleaned[col] < Q1 - threshold * IQR) | (df_cleaned[col] > Q3 + threshold * IQR)]
        df_cleaned = df_cleaned.drop(outliers.index)
        print(f'Dropped {len(outliers)} outliers in {col}.')
# Out:
# Dropped 0 outliers in CLIENTNUM.
# Dropped 2 outliers in Customer_Age.
# Dropped 0 outliers in Dependent_count.
# Dropped 385 outliers in Months_on_book.
# Dropped 0 outliers in Total_Relationship_Count.
# Dropped 308 outliers in Months_Inactive_12_mon.
# Dropped 584 outliers in Contacts_Count_12_mon.
# Dropped 0 outliers in Total_Revolving_Bal.
# Dropped 808 outliers in Total_Trans_Amt.
# Dropped 0 outliers in Total_Trans_Ct.

# %% [markdown]
# <h4><u>Check for missing values</u></h4>

# %%
if (len(df_cleaned[df_cleaned[col].isnull() == True]) > 0):
    print(f'Missing value/s found!')
else:
    print('No missing value/s!')
# Out:
# No missing value/s!

# %% [markdown]
# <h4><u>Rename ambiguous columns</u></h4>

# %%
df_cleaned=df_cleaned.rename(
    columns={
        'Months_Inactive_12_mon': 'Months_Inactive_Past_12_Months',
        'Contacts_Count_12_mon': 'Contacts_Count_Past_12_Months',
        'Total_Revolving_Bal': 'Total_Revolving_Balance',
        'Total_Amt_Chng_Q4_Q1': 'Transaction_Amt_Change_Q4_over_Q1',
        'Total_Trans_Amt': 'Total_Transaction_Amount',
        'Total_Trans_Ct': 'Total_Transaction_Count',
        'Total_Ct_Chng_Q4_Q1': 'Transaction_Count_Change_Q4_over_Q1',
    }
)

# %% [markdown]
# <h4><u>Export dataset for analysis and visualisation</u></h4>

# %%
df_cleaned.to_excel('BankChurnersCleaned.xlsx')

# %%
df_cleaned=df_cleaned.drop(columns=['CLIENTNUM'])

# %% [markdown]
# <h2><u>Data Exploration</u></h2>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_cleaned.head()
# Out:
#       Attrition_Flag  Customer_Age Gender  Dependent_count Education_Level  \
# 0  Existing Customer            45      M                3     High School
# 1  Existing Customer            49      F                5        Graduate
# 3  Existing Customer            40      F                4     High School
# 5  Existing Customer            44      M                2        Graduate
# 6  Existing Customer            51      M                4         Unknown
#
#   Marital_Status Income_Category Card_Category  Months_on_book  \
# 0        Married     $60K - $80K          Blue              39
# 1         Single  Less than $40K          Blue              44
# 3        Unknown  Less than $40K          Blue              34
# 5        Married     $40K - $60K          Blue              36
# 6        Married         $120K +          Gold              46
#
#    Total_Relationship_Count  Months_Inactive_Past_12_Months  \
# 0                         5                               1
# 1                         6                               1
# 3                         3                               4
# 5                         3                               1
# 6                         6                               1
#
#    Contacts_Count_Past_12_Months  Credit_Limit  Total_Revolving_Balance  \
# 0                              3       12691.0                      777
# 1                              2        8256.0                      864
# 3                              1        3313.0                     2517
# 5                              2        4010.0                     1247
# 6                              3       34516.0                     2264
#
#    Avg_Open_To_Buy  Transaction_Amt_Change_Q4_over_Q1  \
# 0          11914.0                              1.335
# 1           7392.0                              1.541
# 3            796.0                              1.405
# 5           2763.0                              1.376
# 6          32252.0                              1.975
#
#    Total_Transaction_Amount  Total_Transaction_Count  \
# 0                      1144                       42
# 1                      1291                       33
# 3                      1171                       20
# 5                      1088                       24
# 6                      1330                       31
#
#    Transaction_Count_Change_Q4_over_Q1  Avg_Utilization_Ratio
# 0                                1.625                  0.061
# 1                                3.714                  0.105
# 3                                2.333                  0.760
# 5                                0.846                  0.311
# 6                                0.722                  0.066

# %%
df_cleaned.describe()
# Out:
#        Customer_Age  Dependent_count  Months_on_book  \
# count   8040.000000      8040.000000     8040.000000
# mean      46.338806         2.408209       35.907214
# std        7.445478         1.271965        6.991000
# min       26.000000         0.000000       18.000000
# 25%       41.000000         2.000000       32.000000
# 50%       46.000000         2.000000       36.000000
# 75%       52.000000         3.000000       40.000000
# max       68.000000         5.000000       53.000000
#
#        Total_Relationship_Count  Months_Inactive_Past_12_Months  \
# count               8040.000000                     8040.000000
# mean                   3.932214                        2.268035
# std                    1.512483                        0.858823
# min                    1.000000                        1.000000
# 25%                    3.000000                        2.000000
# 50%                    4.000000                        2.000000
# 75%                    5.000000                        3.000000
# max                    6.000000                        4.000000
#
#        Contacts_Count_Past_12_Months  Credit_Limit  Total_Revolving_Balance  \
# count                    8040.000000   8040.000000              8040.000000
# mean                        2.512562   8162.550896              1147.994900
# std                         0.927442   8803.717930               815.958232
# min                         1.000000   1438.300000                 0.000000
# 25%                         2.000000   2447.000000               159.000000
# 50%                         3.000000   4198.500000              1257.000000
# 75%                         3.000000  10080.500000              1769.000000
# max                         4.000000  34516.000000              2517.000000
#
#        Avg_Open_To_Buy  Transaction_Amt_Change_Q4_over_Q1  \
# count      8040.000000                        8040.000000
# mean       7014.555995                           0.753408
# std        8815.469105                           0.220990
# min           3.000000                           0.000000
# 25%        1179.000000                           0.621000
# 50%        3123.000000                           0.728000
# 75%        8990.500000                           0.855000
# max       34516.000000                           2.675000
#
#        Total_Transaction_Amount  Total_Transaction_Count  \
# count               8040.000000              8040.000000
# mean                3537.054851                61.398383
# std                 1676.852012                20.058525
# min                  510.000000                10.000000
# 25%                 2077.000000                44.000000
# 50%                 3736.500000                65.000000
# 75%                 4542.000000                78.000000
# max                 8620.000000               113.000000
#
#        Transaction_Count_Change_Q4_over_Q1  Avg_Utilization_Ratio
# count                          8040.000000            8040.000000
# mean                              0.708008               0.284044
# std                               0.243195               0.280200
# min                               0.000000               0.000000
# 25%                               0.571000               0.008750
# 50%                               0.694000               0.187000
# 75%                               0.821000               0.522000
# max                               3.714000               0.999000

# %%
df_cleaned['Attrition_Flag'].value_counts()
# Out:
# Attrition_Flag
# Existing Customer    6703
# Attrited Customer    1337
# Name: count, dtype: int64

# %%
sns.countplot(x='Attrition_Flag', data=df_cleaned, hue='Attrition_Flag', palette=['lightblue', 'steelblue'])
plt.title("Churn vs. Non-Churn Customers")
plt.xlabel("Attrition Flag (0 = Active, 1 = Churned)")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(df_cleaned['Customer_Age'], bins=30, kde=True, color="steelblue")
plt.title("Distribution of Customer Age")
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(df_cleaned['Credit_Limit'], bins=30, kde=True, color="steelblue")
plt.title("Distribution of Credit Limit")
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Gender', hue='Attrition_Flag', data=df_cleaned, palette=['lightblue', 'steelblue'])
plt.title("Churn by Gender")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(y='Income_Category', hue='Attrition_Flag', data=df_cleaned, palette=['lightblue', 'steelblue'])
plt.title("Churn by Income Category")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='Attrition_Flag', y='Credit_Limit', data=df_cleaned, hue='Attrition_Flag', palette=['lightblue', 'steelblue'])
plt.title("Credit Limit vs. Churn")
plt.show()

# %%
sns.pairplot(df[['Customer_Age', 'Credit_Limit', 'Total_Trans_Amt', 'Attrition_Flag']], 
             hue="Attrition_Flag", palette=['lightblue', 'steelblue'])
plt.show()

# %% [markdown]
# <h2><u>Data Modelling</u></h2>

# %% [markdown]
# <h3><i>Defining Features and Target Variable</i></h3>

# %%
X = df_cleaned.drop(columns=['Attrition_Flag'])
y = df_cleaned['Attrition_Flag']

# %%
X
# Out:
#        Customer_Age Gender  Dependent_count Education_Level Marital_Status  \
# 0                45      M                3     High School        Married
# 1                49      F                5        Graduate         Single
# 3                40      F                4     High School        Unknown
# 5                44      M                2        Graduate        Married
# 6                51      M                4         Unknown        Married
# ...             ...    ...              ...             ...            ...
# 10067            49      F                4      Uneducated        Married
# 10089            52      F                5         Unknown        Married
# 10103            51      M                1     High School        Married
# 10119            55      F                3      Uneducated         Single
# 10125            30      M                2        Graduate        Unknown
#
#       Income_Category Card_Category  Months_on_book  Total_Relationship_Count  \
# 0         $60K - $80K          Blue              39                         5
# 1      Less than $40K          Blue              44                         6
# 3      Less than $40K          Blue              34                         3
# 5         $40K - $60K          Blue              36                         3
# 6             $120K +          Gold              46                         6
# ...               ...           ...             ...                       ...
# 10067     $40K - $60K          Blue              36                         5
# 10089  Less than $40K          Blue              36                         4
# 10103    $80K - $120K          Blue              36                         4
# 10119         Unknown          Blue              47                         4
# 10125     $40K - $60K          Blue              36                         4
#
#        Months_Inactive_Past_12_Months  Contacts_Count_Past_12_Months  \
# 0                                   1                              3
# 1                                   1                              2
# 3                                   4                              1
# 5                                   1                              2
# 6                                   1                              3
# ...                               ...                            ...
# 10067                               2                              3
# 10089                               3                              3
# 10103                               3                              4
# 10119                               3                              3
# 10125                               3                              3
#
#        Credit_Limit  Total_Revolving_Balance  Avg_Open_To_Buy  \
# 0           12691.0                      777          11914.0
# 1            8256.0                      864           7392.0
# 3            3313.0                     2517            796.0
# 5            4010.0                     1247           2763.0
# 6           34516.0                     2264          32252.0
# ...             ...                      ...              ...
# 10067        4167.0                        0           4167.0
# 10089        9611.0                        0           9611.0
# 10103       22754.0                        0          22754.0
# 10119       14657.0                     2517          12140.0
# 10125        5281.0                        0           5281.0
#
#        Transaction_Amt_Change_Q4_over_Q1  Total_Transaction_Amount  \
# 0                                  1.335                      1144
# 1                                  1.541                      1291
# 3                                  1.405                      1171
# 5                                  1.376                      1088
# 6                                  1.975                      1330
# ...                                  ...                       ...
# 10067                              0.581                      7590
# 10089                              0.840                      7636
# 10103                              0.799                      8531
# 10119                              0.166                      6009
# 10125                              0.535                      8395
#
#        Total_Transaction_Count  Transaction_Count_Change_Q4_over_Q1  \
# 0                           42                                1.625
# 1                           33                                3.714
# 3                           20                                2.333
# 5                           24                                0.846
# 6                           31                                0.722
# ...                        ...                                  ...
# 10067                       87                                0.776
# 10089                       64                                0.829
# 10103                       77                                0.791
# 10119                       53                                0.514
# 10125                       62                                0.722
#
#        Avg_Utilization_Ratio
# 0                      0.061
# 1                      0.105
# 3                      0.760
# 5                      0.311
# 6                      0.066
# ...                      ...
# 10067                  0.000
# 10089                  0.000
# 10103                  0.000
# 10119                  0.172
# 10125                  0.000
#
# [8040 rows x 19 columns]

# %%
y
# Out:
# 0        Existing Customer
# 1        Existing Customer
# 3        Existing Customer
# 5        Existing Customer
# 6        Existing Customer
#                ...
# 10067    Attrited Customer
# 10089    Attrited Customer
# 10103    Attrited Customer
# 10119    Attrited Customer
# 10125    Attrited Customer
# Name: Attrition_Flag, Length: 8040, dtype: object

# %% [markdown]
# <h3><i>One-Hot Encoding</i></h3>

# %%
X = pd.get_dummies(X, drop_first=True)
X
# Out:
#        Customer_Age  Dependent_count  Months_on_book  \
# 0                45                3              39
# 1                49                5              44
# 3                40                4              34
# 5                44                2              36
# 6                51                4              46
# ...             ...              ...             ...
# 10067            49                4              36
# 10089            52                5              36
# 10103            51                1              36
# 10119            55                3              47
# 10125            30                2              36
#
#        Total_Relationship_Count  Months_Inactive_Past_12_Months  \
# 0                             5                               1
# 1                             6                               1
# 3                             3                               4
# 5                             3                               1
# 6                             6                               1
# ...                         ...                             ...
# 10067                         5                               2
# 10089                         4                               3
# 10103                         4                               3
# 10119                         4                               3
# 10125                         4                               3
#
#        Contacts_Count_Past_12_Months  Credit_Limit  Total_Revolving_Balance  \
# 0                                  3       12691.0                      777
# 1                                  2        8256.0                      864
# 3                                  1        3313.0                     2517
# 5                                  2        4010.0                     1247
# 6                                  3       34516.0                     2264
# ...                              ...           ...                      ...
# 10067                              3        4167.0                        0
# 10089                              3        9611.0                        0
# 10103                              4       22754.0                        0
# 10119                              3       14657.0                     2517
# 10125                              3        5281.0                        0
#
#        Avg_Open_To_Buy  Transaction_Amt_Change_Q4_over_Q1  ...  \
# 0              11914.0                              1.335  ...
# 1               7392.0                              1.541  ...
# 3                796.0                              1.405  ...
# 5               2763.0                              1.376  ...
# 6              32252.0                              1.975  ...
# ...                ...                                ...  ...
# 10067           4167.0                              0.581  ...
# 10089           9611.0                              0.840  ...
# 10103          22754.0                              0.799  ...
# 10119          12140.0                              0.166  ...
# 10125           5281.0                              0.535  ...
#
#        Marital_Status_Single  Marital_Status_Unknown  \
# 0                      False                   False
# 1                       True                   False
# 3                      False                    True
# 5                      False                   False
# 6                      False                   False
# ...                      ...                     ...
# 10067                  False                   False
# 10089                  False                   False
# 10103                  False                   False
# 10119                   True                   False
# 10125                  False                    True
#
#        Income_Category_$40K - $60K  Income_Category_$60K - $80K  \
# 0                            False                         True
# 1                            False                        False
# 3                            False                        False
# 5                             True                        False
# 6                            False                        False
# ...                            ...                          ...
# 10067                         True                        False
# 10089                        False                        False
# 10103                        False                        False
# 10119                        False                        False
# 10125                         True                        False
#
#        Income_Category_$80K - $120K  Income_Category_Less than $40K  \
# 0                             False                           False
# 1                             False                            True
# 3                             False                            True
# 5                             False                           False
# 6                             False                           False
# ...                             ...                             ...
# 10067                         False                           False
# 10089                         False                            True
# 10103                          True                           False
# 10119                         False                           False
# 10125                         False                           False
#
#        Income_Category_Unknown  Card_Category_Gold  Card_Category_Platinum  \
# 0                        False               False                   False
# 1                        False               False                   False
# 3                        False               False                   False
# 5                        False               False                   False
# 6                        False                True                   False
# ...                        ...                 ...                     ...
# 10067                    False               False                   False
# 10089                    False               False                   False
# 10103                    False               False                   False
# 10119                     True               False                   False
# 10125                    False               False                   False
#
#        Card_Category_Silver
# 0                     False
# 1                     False
# 3                     False
# 5                     False
# 6                     False
# ...                     ...
# 10067                 False
# 10089                 False
# 10103                 False
# 10119                 False
# 10125                 False
#
# [8040 rows x 32 columns]

# %% [markdown]
# <h3><i>Train-Test Split</i></h3>

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1, stratify=y)

# %%
X_train
# Out:
#       Customer_Age  Dependent_count  Months_on_book  Total_Relationship_Count  \
# 64              53                2              44                         4
# 2889            38                1              29                         6
# 6739            56                3              44                         6
# 1680            51                2              45                         3
# 4398            51                2              45                         5
# ...            ...              ...             ...                       ...
# 2776            47                4              36                         3
# 7919            60                1              36                         1
# 4122            53                1              38                         4
# 6952            34                1              25                         1
# 8491            49                3              32                         1
#
#       Months_Inactive_Past_12_Months  Contacts_Count_Past_12_Months  \
# 64                                 2                              2
# 2889                               3                              3
# 6739                               3                              4
# 1680                               2                              4
# 4398                               2                              1
# ...                              ...                            ...
# 2776                               3                              3
# 7919                               1                              3
# 4122                               3                              3
# 6952                               2                              3
# 8491                               3                              3
#
#       Credit_Limit  Total_Revolving_Balance  Avg_Open_To_Buy  \
# 64         14734.0                     1634          13100.0
# 2889       34516.0                     1435          33081.0
# 6739        1544.0                        0           1544.0
# 1680        5930.0                        0           5930.0
# 4398        3173.0                     2517            656.0
# ...            ...                      ...              ...
# 2776       17557.0                        0          17557.0
# 7919        2347.0                     1488            859.0
# 4122        1891.0                      922            969.0
# 6952        3074.0                        0           3074.0
# 8491        5400.0                     1426           3974.0
#
#       Transaction_Amt_Change_Q4_over_Q1  ...  Marital_Status_Single  \
# 64                                0.989  ...                   True
# 2889                              1.130  ...                   True
# 6739                              0.315  ...                  False
# 1680                              1.190  ...                  False
# 4398                              0.708  ...                  False
# ...                                 ...  ...                    ...
# 2776                              0.667  ...                  False
# 7919                              0.621  ...                   True
# 4122                              0.812  ...                   True
# 6952                              0.718  ...                  False
# 8491                              0.595  ...                   True
#
#       Marital_Status_Unknown  Income_Category_$40K - $60K  \
# 64                     False                        False
# 2889                   False                        False
# 6739                   False                         True
# 1680                   False                         True
# 4398                   False                        False
# ...                      ...                          ...
# 2776                   False                        False
# 7919                   False                        False
# 4122                   False                        False
# 6952                    True                        False
# 8491                   False                         True
#
#       Income_Category_$60K - $80K  Income_Category_$80K - $120K  \
# 64                          False                         False
# 2889                        False                          True
# 6739                        False                         False
# 1680                        False                         False
# 4398                        False                         False
# ...                           ...                           ...
# 2776                         True                         False
# 7919                        False                         False
# 4122                        False                         False
# 6952                        False                         False
# 8491                        False                         False
#
#       Income_Category_Less than $40K  Income_Category_Unknown  \
# 64                             False                    False
# 2889                           False                    False
# 6739                           False                    False
# 1680                           False                    False
# 4398                           False                    False
# ...                              ...                      ...
# 2776                           False                    False
# 7919                            True                    False
# 4122                           False                    False
# 6952                            True                    False
# 8491                           False                    False
#
#       Card_Category_Gold  Card_Category_Platinum  Card_Category_Silver
# 64                 False                   False                 False
# 2889               False                   False                  True
# 6739               False                   False                 False
# 1680               False                   False                 False
# 4398               False                   False                 False
# ...                  ...                     ...                   ...
# 2776               False                   False                 False
# 7919               False                   False                 False
# 4122               False                   False                 False
# 6952               False                   False                 False
# 8491               False                   False                 False
#
# [5628 rows x 32 columns]

# %%
X_test
# Out:
#       Customer_Age  Dependent_count  Months_on_book  Total_Relationship_Count  \
# 636             46                3              32                         6
# 6947            43                5              33                         4
# 600             45                2              40                         6
# 8563            36                2              36                         2
# 4851            41                3              31                         4
# ...            ...              ...             ...                       ...
# 4980            45                4              38                         6
# 2556            45                2              36                         6
# 2835            36                1              23                         4
# 1025            42                3              36                         1
# 3856            43                3              23                         5
#
#       Months_Inactive_Past_12_Months  Contacts_Count_Past_12_Months  \
# 636                                2                              3
# 6947                               2                              1
# 600                                3                              1
# 8563                               2                              1
# 4851                               3                              2
# ...                              ...                            ...
# 4980                               3                              2
# 2556                               4                              3
# 2835                               3                              1
# 1025                               1                              3
# 3856                               3                              3
#
#       Credit_Limit  Total_Revolving_Balance  Avg_Open_To_Buy  \
# 636        11477.0                        0          11477.0
# 6947        1438.3                        0           1438.3
# 600        11710.0                      693          11017.0
# 8563        6763.0                     1660           5103.0
# 4851        5655.0                     1154           4501.0
# ...            ...                      ...              ...
# 4980        5583.0                        0           5583.0
# 2556       17156.0                     2517          14639.0
# 2835        1438.3                      928            510.3
# 1025       34516.0                      781          33735.0
# 3856        4284.0                     1094           3190.0
#
#       Transaction_Amt_Change_Q4_over_Q1  ...  Marital_Status_Single  \
# 636                               0.767  ...                  False
# 6947                              0.643  ...                   True
# 600                               0.914  ...                  False
# 8563                              0.573  ...                   True
# 4851                              0.702  ...                   True
# ...                                 ...  ...                    ...
# 4980                              0.748  ...                  False
# 2556                              0.717  ...                  False
# 2835                              0.851  ...                   True
# 1025                              0.803  ...                  False
# 3856                              0.630  ...                  False
#
#       Marital_Status_Unknown  Income_Category_$40K - $60K  \
# 636                    False                         True
# 6947                   False                         True
# 600                    False                        False
# 8563                   False                         True
# 4851                   False                         True
# ...                      ...                          ...
# 4980                   False                        False
# 2556                   False                        False
# 2835                   False                        False
# 1025                   False                        False
# 3856                    True                        False
#
#       Income_Category_$60K - $80K  Income_Category_$80K - $120K  \
# 636                         False                         False
# 6947                        False                         False
# 600                         False                          True
# 8563                        False                         False
# 4851                        False                         False
# ...                           ...                           ...
# 4980                        False                         False
# 2556                        False                         False
# 2835                        False                         False
# 1025                        False                          True
# 3856                        False                         False
#
#       Income_Category_Less than $40K  Income_Category_Unknown  \
# 636                            False                    False
# 6947                           False                    False
# 600                            False                    False
# 8563                           False                    False
# 4851                           False                    False
# ...                              ...                      ...
# 4980                            True                    False
# 2556                           False                     True
# 2835                            True                    False
# 1025                           False                    False
# 3856                            True                    False
#
#       Card_Category_Gold  Card_Category_Platinum  Card_Category_Silver
# 636                False                   False                 False
# 6947               False                   False                 False
# 600                False                   False                 False
# 8563               False                   False                 False
# 4851               False                   False                 False
# ...                  ...                     ...                   ...
# 4980               False                   False                 False
# 2556               False                   False                 False
# 2835               False                   False                 False
# 1025               False                   False                 False
# 3856               False                   False                 False
#
# [2412 rows x 32 columns]

# %%
y_train
# Out:
# 64      Existing Customer
# 2889    Existing Customer
# 6739    Attrited Customer
# 1680    Existing Customer
# 4398    Existing Customer
#               ...
# 2776    Existing Customer
# 7919    Existing Customer
# 4122    Existing Customer
# 6952    Attrited Customer
# 8491    Existing Customer
# Name: Attrition_Flag, Length: 5628, dtype: object

# %%
y_test
# Out:
# 636     Existing Customer
# 6947    Existing Customer
# 600     Existing Customer
# 8563    Existing Customer
# 4851    Attrited Customer
#               ...
# 4980    Existing Customer
# 2556    Attrited Customer
# 2835    Existing Customer
# 1025    Attrited Customer
# 3856    Existing Customer
# Name: Attrition_Flag, Length: 2412, dtype: object

# %% [markdown]
# <h3><i>Feature Scaling for Logistic Regression</i></h3>

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# <h3><i>Train Models</i></h3>

# %% [markdown]
# <h4><u>Logistic Regression</u></h4>

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

log_reg = LogisticRegression(max_iter=500)
log_reg.fit(X_train_scaled, y_train)

y_pred_log = log_reg.predict(X_test_scaled)
print("Logistic Regression Accuracy:", accuracy_score(y_test, y_pred_log))
# Out:
# Logistic Regression Accuracy: 0.9067164179104478

# %% [markdown]
# <h4><u>Decision Tree</h4>

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier(max_depth=5, random_state=42)
dt.fit(X_train, y_train)

y_pred_dt = dt.predict(X_test)
print("Decision Tree Accuracy:", accuracy_score(y_test, y_pred_dt))
# Out:
# Decision Tree Accuracy: 0.9286898839137645

# %% [markdown]
# <h4><u>XGBoost</u></h4>

# %%
from xgboost import XGBClassifier

y_train_xgb = y_train.map({'Attrited Customer': 1, 'Existing Customer': 0})
y_test_xgb = y_test.map({'Attrited Customer': 1, 'Existing Customer': 0})

xgb = XGBClassifier(eval_metric='logloss')
xgb.fit(X_train, y_train_xgb)

y_pred_xgb = xgb.predict(X_test)
print("XGBoost Accuracy:", accuracy_score(y_test_xgb, y_pred_xgb))
# Out:
# XGBoost Accuracy: 0.9660033167495854

# %% [markdown]
# <h3><i>Model Evaluation</i></h3>

# %%
from sklearn.metrics import classification_report, roc_auc_score

print("Logistic Regression:\n", classification_report(y_test, y_pred_log))
print("-------------------------------------------------------------")
print("Decision Tree:\n", classification_report(y_test, y_pred_dt))
print("-------------------------------------------------------------")
print("XGBoost:\n", classification_report(y_test_xgb, y_pred_xgb))
print("XGBoost ROC-AUC Score:", roc_auc_score(y_test_xgb, y_pred_xgb))
# Out:
# Logistic Regression:
#                     precision    recall  f1-score   support
#
# Attrited Customer       0.76      0.64      0.70       401
# Existing Customer       0.93      0.96      0.94      2011
#
#          accuracy                           0.91      2412
#         macro avg       0.84      0.80      0.82      2412
#      weighted avg       0.90      0.91      0.90      2412
#
# -------------------------------------------------------------
# Decision Tree:
#                     precision    recall  f1-score   support
#
# Attrited Customer       0.80      0.77      0.78       401
# Existing Customer       0.95      0.96      0.96      2011
#
#          accuracy                           0.93      2412
#         macro avg       0.88      0.86      0.87      2412
#      weighted avg       0.93      0.93      0.93      2412
#
# -------------------------------------------------------------
# XGBoost:
#                precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      2011
#            1       0.93      0.86      0.89       401
#
#     accuracy                           0.97      2412
#    macro avg       0.95      0.92      0.94      2412
# weighted avg       0.97      0.97      0.97      2412
#
# XGBoost ROC-AUC Score: 0.9237101180415446

# %% [markdown]
# <h3><i>Model Improvement - XGBoost</i></h3>

# %% [markdown]
# <h4>Feature Engineering</h4>

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Get feature importance from trained XGBoost model
feature_importance = xgb.feature_importances_

# Create a DataFrame to sort & visualize
feature_imp_df = pd.DataFrame({'Feature': X_train.columns, 'Importance': feature_importance})
feature_imp_df = feature_imp_df.sort_values(by='Importance', ascending=False)

# Plot feature importance
plt.figure(figsize=(10,6))
plt.barh(feature_imp_df['Feature'], feature_imp_df['Importance'], color='skyblue')
plt.xlabel("Feature Importance Score")
plt.ylabel("Features")
plt.title("Feature Importance from XGBoost")
plt.gca().invert_yaxis()  # Flip to show the highest at the top
plt.show()

# %%
from sklearn.feature_selection import RFE
from xgboost import XGBClassifier

xgb = XGBClassifier(eval_metric='logloss')

selector = RFE(xgb, n_features_to_select=10)  # Keep top 10 features
selector.fit(X_train, y_train_xgb)

selected_features = X_train.columns[selector.support_]

print('SELECTED FEATURES:')
for feature in selected_features:
    print(feature)
print()

X_train_selected = X_train[selected_features]
X_test_selected = X_test[selected_features]

xgb.fit(X_train_selected, y_train_xgb)
y_pred_xgb = xgb.predict(X_test_selected)

print("XGBoost Accuracy after feature selection:", accuracy_score(y_test_xgb, y_pred_xgb))
# Out:
# SELECTED FEATURES:
# Customer_Age
# Total_Relationship_Count
# Months_Inactive_Past_12_Months
# Total_Revolving_Balance
# Transaction_Amt_Change_Q4_over_Q1
# Total_Transaction_Amount
# Total_Transaction_Count
# Transaction_Count_Change_Q4_over_Q1
# Gender_M
# Marital_Status_Married
#
# XGBoost Accuracy after feature selection: 0.9631011608623549

# %% [markdown]
# <h4>Handling class imbalance</h4>

# %%
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score

scale_pos_weight = y_train_xgb.value_counts()[0] / y_train_xgb.value_counts()[1]

xgb = XGBClassifier(eval_metric='logloss', scale_pos_weight=scale_pos_weight)

xgb.fit(X_train_selected, y_train_xgb)

y_pred_xgb = xgb.predict(X_test_selected)

print("XGBoost Accuracy after handling class imbalance:", accuracy_score(y_test_xgb, y_pred_xgb))
# Out:
# XGBoost Accuracy after handling class imbalance: 0.964759535655058

# %% [markdown]
# <h4>Hyperparameter Tuning</h4>

# %%
import optuna
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

def objective(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 500),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'subsample': trial.suggest_float('subsample', 0.7, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.7, 1.0),
        'gamma': trial.suggest_float('gamma', 0.01, 1.0),
        'reg_alpha': trial.suggest_float('reg_alpha', 0.01, 1.0),
        'reg_lambda': trial.suggest_float('reg_lambda', 0.01, 10.0),
        'scale_pos_weight': y_train_xgb.value_counts()[0] / y_train_xgb.value_counts()[1],  # Handle class imbalance
        'eval_metric': 'logloss'
    }
    
    # Train model
    model = XGBClassifier(**params)
    model.fit(X_train_selected, y_train_xgb)
    
    # Predict on test set
    y_pred = model.predict(X_test_selected)
    
    # Return accuracy as the metric to optimize
    return accuracy_score(y_test_xgb, y_pred)

# Run Optuna optimization
study = optuna.create_study(direction='maximize')  # Maximize accuracy
study.optimize(objective, n_trials=30)  # Run 30 trials

# Print best parameters
print(f"Best parameters: {study.best_params} \n")

best_xgb = XGBClassifier(**study.best_params)
best_xgb.fit(X_train_selected, y_train_xgb)

y_pred_xgb = best_xgb.predict(X_test_selected)

print("Optimized XGBoost Accuracy:", accuracy_score(y_test_xgb, y_pred_xgb))
# Out:
# [I 2025-02-18 21:16:26,258] A new study created in memory with name: no-name-0d6fe7d4-5ef6-42aa-a184-d390cb105907
# [I 2025-02-18 21:16:26,367] Trial 0 finished with value: 0.966832504145937 and parameters: {'n_estimators': 359, 'learning_rate': 0.06410637138322285, 'max_depth': 10, 'subsample': 0.8310786880954678, 'colsample_bytree': 0.7143261655371005, 'gamma': 0.880287238443403, 'reg_alpha': 0.7361162305637643, 'reg_lambda': 9.069731521186965}. Best is trial 0 with value: 0.966832504145937.
# [I 2025-02-18 21:16:26,424] Trial 1 finished with value: 0.9664179104477612 and parameters: {'n_estimators': 205, 'learning_rate': 0.12077530093125961, 'max_depth': 5, 'subsample': 0.7676630331352211, 'colsample_bytree': 0.8266116171111326, 'gamma': 0.8664103289694287, 'reg_alpha': 0.8601557406022176, 'reg_lambda': 8.412909296446271}. Best is trial 0 with value: 0.966832504145937.
# [I 2025-02-18 21:16:26,540] Trial 2 finished with value: 0.966832504145937 and parameters: {'n_estimators': 445, 'learning_rate': 0.05067379771820776, 'max_depth': 5, 'subsample': 0.7296278111358377, 'colsample_bytree': 0.7457233620817745, 'gamma': 0.382124350955758, 'reg_alpha': 0.6987454310189435, 'reg_lambda': 3.9631591504698256}. Best is trial 0 with value: 0.966832504145937.
# [I 2025-02-18 21:16:26,587] Trial 3 finished with value: 0.9643449419568823 and parameters: {'n_estimators': 293, 'learning_rate': 0.19892201831392742, 'max_depth': 8, 'subsample': 0.9056927573433328, 'colsample_bytree': 0.7511668000479171, 'gamma': 0.7446221295591576, 'reg_alpha': 0.09447759173633255, 'reg_lambda': 0.4724230511626698}. Best is trial 0 with value: 0.966832504145937.
# [I 2025-02-18 21:16:26,668] Trial 4 finished with value: 0.9643449419568823 and parameters: {'n_estimators': 297, 'learning_rate': 0.09447122342315047, 'max_depth': 8, 'subsample': 0.8893651116755784, 'colsample_bytree': 0.7826260122308294, 'gamma': 0.5756730242740977, 'reg_alpha': 0.8884072997879507, 'reg_lambda': 7.252571831941019}. Best is trial 0 with value: 0.966832504145937.
# [I 2025-02-18 21:16:26,718] Trial 5 finished with value: 0.9643449419568823 and parameters: {'n_estimators': 262, 'learning_rate': 0.11739265788174276, 'max_depth': 3, 'subsample': 0.9199722824503719, 'colsample_bytree': 0.9972222400486199, 'gamma': 0.7246378300126024, 'reg_alpha': 0.24503465418806292, 'reg_lambda': 0.3231514029958638}. Best is trial 0 with value: 0.966832504145937.
# [I 2025-02-18 21:16:26,759] Trial 6 finished with value: 0.9660033167495854 and parameters: {'n_estimators': 178, 'learning_rate': 0.18471624773649548, 'max_depth': 5, 'subsample': 0.9481504122625974, 'colsample_bytree': 0.9056774852788905, 'gamma': 0.574656328508882, 'reg_alpha': 0.5300642398405111, 'reg_lambda': 5.81866536416224}. Best is trial 0 with value: 0.966832504145937.
# [I 2025-02-18 21:16:26,917] Trial 7 finished with value: 0.9651741293532339 and parameters: {'n_estimators': 338, 'learning_rate': 0.02874264128958454, 'max_depth': 10, 'subsample': 0.935154945710284, 'colsample_bytree': 0.851610410731691, 'gamma': 0.8704417926380147, 'reg_alpha': 0.18913093021157804, 'reg_lambda': 1.6302991547802348}. Best is trial 0 with value: 0.966832504145937.
# [I 2025-02-18 21:16:26,990] Trial 8 finished with value: 0.964759535655058 and parameters: {'n_estimators': 315, 'learning_rate': 0.16548875344019554, 'max_depth': 6, 'subsample': 0.7903914277984957, 'colsample_bytree': 0.8972396155755281, 'gamma': 0.21036021824621287, 'reg_alpha': 0.9716188849694474, 'reg_lambda': 1.1918557060217927}. Best is trial 0 with value: 0.966832504145937.
# [I 2025-02-18 21:16:27,131] Trial 9 finished with value: 0.9664179104477612 and parameters: {'n_estimators': 461, 'learning_rate': 0.1035367055231644, 'max_depth': 7, 'subsample': 0.8541901727338298, 'colsample_bytree': 0.8072711639695735, 'gamma': 0.15354963199096996, 'reg_alpha': 0.8171140422412771, 'reg_lambda': 8.169281833278742}. Best is trial 0 with value: 0.966832504145937.
# [I 2025-02-18 21:16:27,200] Trial 10 finished with value: 0.9593698175787728 and parameters: {'n_estimators': 111, 'learning_rate': 0.06380714609684407, 'max_depth': 10, 'subsample': 0.8314596508588843, 'colsample_bytree': 0.7093879325629222, 'gamma': 0.9614782602406104, 'reg_alpha': 0.46144204060365296, 'reg_lambda': 9.690656843069853}. Best is trial 0 with value: 0.966832504145937.
# [I 2025-02-18 21:16:27,287] Trial 11 finished with value: 0.931592039800995 and parameters: {'n_estimators': 432, 'learning_rate': 0.010537292377803632, 'max_depth': 3, 'subsample': 0.7017687649280284, 'colsample_bytree': 0.7006305503199229, 'gamma': 0.37670417253424887, 'reg_alpha': 0.6457092447555752, 'reg_lambda': 3.7257044193787427}. Best is trial 0 with value: 0.966832504145937.
# [I 2025-02-18 21:16:27,401] Trial 12 finished with value: 0.9655887230514096 and parameters: {'n_estimators': 412, 'learning_rate': 0.05952644561101201, 'max_depth': 5, 'subsample': 0.7146568259025795, 'colsample_bytree': 0.7479249622338854, 'gamma': 0.38740062800427316, 'reg_alpha': 0.700987640665821, 'reg_lambda': 3.9163774139088283}. Best is trial 0 with value: 0.966832504145937.
# [I 2025-02-18 21:16:27,595] Trial 13 finished with value: 0.966832504145937 and parameters: {'n_estimators': 373, 'learning_rate': 0.04986500511393652, 'max_depth': 9, 'subsample': 0.9859228671834969, 'colsample_bytree': 0.7511514033203673, 'gamma': 0.04252038431058269, 'reg_alpha': 0.4487825644600744, 'reg_lambda': 5.548484157077356}. Best is trial 0 with value: 0.966832504145937.
# [I 2025-02-18 21:16:27,711] Trial 14 finished with value: 0.9651741293532339 and parameters: {'n_estimators': 499, 'learning_rate': 0.07725802818137173, 'max_depth': 4, 'subsample': 0.7647817776948242, 'colsample_bytree': 0.7282193406341491, 'gamma': 0.41992080143032257, 'reg_alpha': 0.68530592037303, 'reg_lambda': 2.980269803922693}. Best is trial 0 with value: 0.966832504145937.
# [I 2025-02-18 21:16:27,865] Trial 15 finished with value: 0.9660033167495854 and parameters: {'n_estimators': 381, 'learning_rate': 0.03420359024620458, 'max_depth': 7, 'subsample': 0.8060450887381857, 'colsample_bytree': 0.7858143715296377, 'gamma': 0.2829183367344752, 'reg_alpha': 0.559621136327469, 'reg_lambda': 6.574106881228854}. Best is trial 0 with value: 0.966832504145937.
# [I 2025-02-18 21:16:27,992] Trial 16 finished with value: 0.9672470978441128 and parameters: {'n_estimators': 494, 'learning_rate': 0.07843165682308915, 'max_depth': 6, 'subsample': 0.7461861586472842, 'colsample_bytree': 0.8642493175720145, 'gamma': 0.6600904232287461, 'reg_alpha': 0.3499285302933197, 'reg_lambda': 4.408115648260753}. Best is trial 16 with value: 0.9672470978441128.
# [I 2025-02-18 21:16:28,127] Trial 17 finished with value: 0.9639303482587065 and parameters: {'n_estimators': 491, 'learning_rate': 0.08050392284839387, 'max_depth': 8, 'subsample': 0.8527004567079672, 'colsample_bytree': 0.8746297922191177, 'gamma': 0.696296701520162, 'reg_alpha': 0.3368727713426421, 'reg_lambda': 4.7800121281199655}. Best is trial 16 with value: 0.9672470978441128.
# [I 2025-02-18 21:16:28,209] Trial 18 finished with value: 0.9684908789386402 and parameters: {'n_estimators': 240, 'learning_rate': 0.12394880251847587, 'max_depth': 6, 'subsample': 0.7475144009090238, 'colsample_bytree': 0.9451511720674202, 'gamma': 0.9482843718762637, 'reg_alpha': 0.3729808238011625, 'reg_lambda': 9.667993386302095}. Best is trial 18 with value: 0.9684908789386402.
# [I 2025-02-18 21:16:28,279] Trial 19 finished with value: 0.9676616915422885 and parameters: {'n_estimators': 237, 'learning_rate': 0.13771318149015133, 'max_depth': 6, 'subsample': 0.7438253176983901, 'colsample_bytree': 0.9552667423396541, 'gamma': 0.9908567116983387, 'reg_alpha': 0.3552810039993109, 'reg_lambda': 2.644041687859089}. Best is trial 18 with value: 0.9684908789386402.
# [I 2025-02-18 21:16:28,340] Trial 20 finished with value: 0.9655887230514096 and parameters: {'n_estimators': 222, 'learning_rate': 0.1584111772576155, 'max_depth': 6, 'subsample': 0.7913076786058184, 'colsample_bytree': 0.9649777601695294, 'gamma': 0.9875697170845418, 'reg_alpha': 0.04604483114632896, 'reg_lambda': 2.492725769298935}. Best is trial 18 with value: 0.9684908789386402.
# [I 2025-02-18 21:16:28,415] Trial 21 finished with value: 0.9660033167495854 and parameters: {'n_estimators': 244, 'learning_rate': 0.13653679088684673, 'max_depth': 6, 'subsample': 0.745575811606187, 'colsample_bytree': 0.9416292350266195, 'gamma': 0.801429185055644, 'reg_alpha': 0.3360256939268461, 'reg_lambda': 2.5194321839630267}. Best is trial 18 with value: 0.9684908789386402.
# [I 2025-02-18 21:16:28,483] Trial 22 finished with value: 0.9676616915422885 and parameters: {'n_estimators': 153, 'learning_rate': 0.13772915383604298, 'max_depth': 7, 'subsample': 0.7462351743559583, 'colsample_bytree': 0.9367977729499679, 'gamma': 0.6113616708574803, 'reg_alpha': 0.3846959559895391, 'reg_lambda': 5.338255177056861}. Best is trial 18 with value: 0.9684908789386402.
# [I 2025-02-18 21:16:28,541] Trial 23 finished with value: 0.9643449419568823 and parameters: {'n_estimators': 139, 'learning_rate': 0.1411885850904223, 'max_depth': 7, 'subsample': 0.7625626855106299, 'colsample_bytree': 0.9399929798544758, 'gamma': 0.9832066926475123, 'reg_alpha': 0.22316388755335273, 'reg_lambda': 7.119416436450068}. Best is trial 18 with value: 0.9684908789386402.
# [I 2025-02-18 21:16:28,592] Trial 24 finished with value: 0.9660033167495854 and parameters: {'n_estimators': 172, 'learning_rate': 0.14104103090199052, 'max_depth': 4, 'subsample': 0.729149970400036, 'colsample_bytree': 0.9952630358825625, 'gamma': 0.8115018463615312, 'reg_alpha': 0.40716707466728114, 'reg_lambda': 5.552176820360837}. Best is trial 18 with value: 0.9684908789386402.
# [I 2025-02-18 21:16:28,658] Trial 25 finished with value: 0.9651741293532339 and parameters: {'n_estimators': 165, 'learning_rate': 0.1571167324749201, 'max_depth': 7, 'subsample': 0.7893634479952675, 'colsample_bytree': 0.9565139292695958, 'gamma': 0.6090676394118998, 'reg_alpha': 0.5976311654097555, 'reg_lambda': 9.950019443687726}. Best is trial 18 with value: 0.9684908789386402.
# [I 2025-02-18 21:16:28,746] Trial 26 finished with value: 0.964759535655058 and parameters: {'n_estimators': 264, 'learning_rate': 0.12563250521562214, 'max_depth': 8, 'subsample': 0.7023410156652032, 'colsample_bytree': 0.9049785234435465, 'gamma': 0.4897133321007371, 'reg_alpha': 0.28062906378207614, 'reg_lambda': 1.5503013233763738}. Best is trial 18 with value: 0.9684908789386402.
# [I 2025-02-18 21:16:28,785] Trial 27 finished with value: 0.9631011608623549 and parameters: {'n_estimators': 104, 'learning_rate': 0.17308289086279924, 'max_depth': 4, 'subsample': 0.7384072634584525, 'colsample_bytree': 0.9709110406786999, 'gamma': 0.917786491095552, 'reg_alpha': 0.15040237160766343, 'reg_lambda': 6.420192542193846}. Best is trial 18 with value: 0.9684908789386402.
# [I 2025-02-18 21:16:28,867] Trial 28 finished with value: 0.966832504145937 and parameters: {'n_estimators': 207, 'learning_rate': 0.10388393718306493, 'max_depth': 9, 'subsample': 0.815230351775843, 'colsample_bytree': 0.9225858814685128, 'gamma': 0.7847680905500081, 'reg_alpha': 0.41511536410186306, 'reg_lambda': 8.448884582008205}. Best is trial 18 with value: 0.9684908789386402.
# [I 2025-02-18 21:16:28,923] Trial 29 finished with value: 0.9651741293532339 and parameters: {'n_estimators': 143, 'learning_rate': 0.130641107835948, 'max_depth': 6, 'subsample': 0.7716386048212591, 'colsample_bytree': 0.8835860139200834, 'gamma': 0.8960416422971524, 'reg_alpha': 0.3059905306115022, 'reg_lambda': 3.234729775866036}. Best is trial 18 with value: 0.9684908789386402.
# Best parameters: {'n_estimators': 240, 'learning_rate': 0.12394880251847587, 'max_depth': 6, 'subsample': 0.7475144009090238, 'colsample_bytree': 0.9451511720674202, 'gamma': 0.9482843718762637, 'reg_alpha': 0.3729808238011625, 'reg_lambda': 9.667993386302095}
#
# Optimized XGBoost Accuracy: 0.9618573797678275

# %% [markdown]
# <h3>K-Folds Cross-Validation</h3>

# %%
from sklearn.model_selection import KFold, cross_val_score

# %% [markdown]
# <h4>Logistic Regression</h4>

# %%
kf = KFold(n_splits=5, random_state=1, shuffle=True)
cv_scores = cross_val_score(log_reg, X_train, y_train, cv=kf, scoring='accuracy')
print(f"Cross-Validation Scores: {cv_scores}")
print(f"Mean Cross-Validation Score: {cv_scores.mean():.3f}")
# Out:
# /Users/lance/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/lance/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/lance/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/lance/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Cross-Validation Scores: [0.89609236 0.89076377 0.89609236 0.89688889 0.89244444]
# Mean Cross-Validation Score: 0.894
# /Users/lance/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# <h4>Decision Tree</h4>

# %%
kf = KFold(n_splits=5, random_state=1, shuffle=True)
cv_scores = cross_val_score(dt, X_train, y_train, cv=kf, scoring='accuracy')
print(f"Cross-Validation Scores: {cv_scores}")
print(f"Mean Cross-Validation Score: {cv_scores.mean():.3f}")
# Out:
# Cross-Validation Scores: [0.92895204 0.92362345 0.94316163 0.93688889 0.93777778]
# Mean Cross-Validation Score: 0.934

# %% [markdown]
# <h4>XGBoost</h4>

# %%
kf = KFold(n_splits=5, random_state=1, shuffle=True)
cv_scores = cross_val_score(xgb, X_train, y_train_xgb, cv=kf, scoring='accuracy')
print(f"Cross-Validation Scores: {cv_scores}")
print(f"Mean Cross-Validation Score: {cv_scores.mean():.3f}")
# Out:
# Cross-Validation Scores: [0.96092362 0.96358792 0.96625222 0.96977778 0.96355556]
# Mean Cross-Validation Score: 0.965

# %% [markdown]
# <h4>For deployment of model</h4>

# %%
best_xgb.save_model('xgboost_model.json')

# %%
X_train_selected.median()
# Out:
# Customer_Age                             46.000
# Total_Relationship_Count                  4.000
# Months_Inactive_Past_12_Months            2.000
# Total_Revolving_Balance                1256.500
# Transaction_Amt_Change_Q4_over_Q1         0.729
# Total_Transaction_Amount               3723.000
# Total_Transaction_Count                  65.000
# Transaction_Count_Change_Q4_over_Q1       0.696
# Gender_M                                  0.000
# Marital_Status_Married                    0.000
# dtype: float64

# %%
train_data = pd.concat([X_train_selected, y_train], axis=1)

# %%
train_data
# Out:
#       Customer_Age  Total_Relationship_Count  Months_Inactive_Past_12_Months  \
# 64              53                         4                               2
# 2889            38                         6                               3
# 6739            56                         6                               3
# 1680            51                         3                               2
# 4398            51                         5                               2
# ...            ...                       ...                             ...
# 2776            47                         3                               3
# 7919            60                         1                               1
# 4122            53                         4                               3
# 6952            34                         1                               2
# 8491            49                         1                               3
#
#       Total_Revolving_Balance  Transaction_Amt_Change_Q4_over_Q1  \
# 64                       1634                              0.989
# 2889                     1435                              1.130
# 6739                        0                              0.315
# 1680                        0                              1.190
# 4398                     2517                              0.708
# ...                       ...                                ...
# 2776                        0                              0.667
# 7919                     1488                              0.621
# 4122                      922                              0.812
# 6952                        0                              0.718
# 8491                     1426                              0.595
#
#       Total_Transaction_Amount  Total_Transaction_Count  \
# 64                        1289                       23
# 2889                      4238                       85
# 6739                      1902                       35
# 1680                      2041                       32
# 4398                      4030                       73
# ...                        ...                      ...
# 2776                      2142                       62
# 7919                      3977                       83
# 4122                      3822                       69
# 6952                      2721                       54
# 8491                      4643                       80
#
#       Transaction_Count_Change_Q4_over_Q1  Gender_M  Marital_Status_Married  \
# 64                                  0.917      True                   False
# 2889                                0.809      True                   False
# 6739                                0.400     False                    True
# 1680                                0.684     False                    True
# 4398                                0.622      True                    True
# ...                                   ...       ...                     ...
# 2776                                0.378      True                    True
# 7919                                0.886     False                   False
# 4122                                0.533      True                   False
# 6952                                0.688     False                   False
# 8491                                0.702     False                   False
#
#          Attrition_Flag
# 64    Existing Customer
# 2889  Existing Customer
# 6739  Attrited Customer
# 1680  Existing Customer
# 4398  Existing Customer
# ...                 ...
# 2776  Existing Customer
# 7919  Existing Customer
# 4122  Existing Customer
# 6952  Attrited Customer
# 8491  Existing Customer
#
# [5628 rows x 11 columns]

# %%
attrited_customers_data = train_data[train_data['Attrition_Flag']=='Attrited Customer']

# %%
attrited_customers_data=attrited_customers_data.drop(columns=['Attrition_Flag'])

# %%
attrited_customers_data.median()
# Out:
# Customer_Age                             46.000
# Total_Relationship_Count                  3.000
# Months_Inactive_Past_12_Months            3.000
# Total_Revolving_Balance                   0.000
# Transaction_Amt_Change_Q4_over_Q1         0.688
# Total_Transaction_Amount               2286.000
# Total_Transaction_Count                  43.000
# Transaction_Count_Change_Q4_over_Q1       0.516
# Gender_M                                  0.000
# Marital_Status_Married                    0.000
# dtype: float64

# %%
import shap
import pandas as pd

# Initialize SHAP explainer
explainer = shap.TreeExplainer(best_xgb)

# Define the test sample as a dictionary
test_sample = {
    "Customer_Age": 46.000,
    "Total_Relationship_Count": 3.000,
    "Months_Inactive_Past_12_Months": 3.000,
    "Total_Revolving_Balance": 0.000,
    "Transaction_Amt_Change_Q4_over_Q1": 0.688,
    "Total_Transaction_Amount": 2286.000,
    "Total_Transaction_Count": 43.000,
    "Transaction_Count_Change_Q4_over_Q1": 0.516,
    "Gender_M": 0.000,
    "Marital_Status_Married": 0.000,
}

# Convert to a DataFrame (it must match the training feature format)
X_test_sample = pd.DataFrame([test_sample])

# Compute SHAP values for your test set
shap_values = explainer.shap_values(X_test_sample)

# Plot global feature importance (for overall model behavior)
shap.summary_plot(shap_values, X_test_sample)

shap.initjs()

shap.waterfall_plot(shap.Explanation(values=shap_values[0], base_values=explainer.expected_value, data=X_test_sample.iloc[0]))

shap.decision_plot(explainer.expected_value, shap_values, X_test_sample)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
